# %%
import pandas as pd

# %% [markdown]
# # import data

# %%
dataset=pd.read_csv('datasets/data_stocks.csv')

# %%
dataset.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN    ...     NYSE.WYN  \
# 0    102.2300      85.2200       59.760       121.52    ...       84.370
# 1    102.1400      85.6500       59.840       121.48    ...       84.370
# 2    102.2125      85.5100       59.795       121.93    ...       84.585
# 3    102.1400      85.4872       59.620       121.44    ...       84.460
# 4    102.0600      85.7001       59.620       121.60    ...       84.470
#
#    NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 0   119.035     44.40    39.88     82.03      7.36     50.22     63.86
# 1   119.035     44.11    39.88     82.03      7.38     50.22     63.74
# 2   119.260     44.09    39.98     82.02      7.36     50.12     63.75
# 3   119.260     44.25    39.99     82.02      7.35     50.16     63.88
# 4   119.610     44.11    39.96     82.03      7.36     50.20     63.91
#
#    NYSE.ZBH  NYSE.ZTS
# 0   122.000    53.350
# 1   121.770    53.350
# 2   121.700    53.365
# 3   121.700    53.380
# 4   121.695    53.240
#
# [5 rows x 502 columns]

# %%
columns=dataset.columns.values.tolist()

# %%
columns
# Out:
# ['DATE',
#  'SP500',
#  'NASDAQ.AAL',
#  'NASDAQ.AAPL',
#  'NASDAQ.ADBE',
#  'NASDAQ.ADI',
#  'NASDAQ.ADP',
#  'NASDAQ.ADSK',
#  'NASDAQ.AKAM',
#  'NASDAQ.ALXN',
#  'NASDAQ.AMAT',
#  'NASDAQ.AMD',
#  'NASDAQ.AMGN',
#  'NASDAQ.AMZN',
#  'NASDAQ.ATVI',
#  'NASDAQ.AVGO',
#  'NASDAQ.BBBY',
#  'NASDAQ.BIIB',
#  'NASDAQ.CA',
#  'NASDAQ.CBOE',
#  'NASDAQ.CELG',
#  'NASDAQ.CERN',
#  'NASDAQ.CHRW',
#  'NASDAQ.CHTR',
#  'NASDAQ.CINF',
#  'NASDAQ.CMCSA',
#  'NASDAQ.CME',
#  'NASDAQ.COST',
#  'NASDAQ.CSCO',
#  'NASDAQ.CSX',
#  'NASDAQ.CTAS',
#  'NASDAQ.CTSH',
#  'NASDAQ.CTXS',
#  'NASDAQ.DISCA',
#  'NASDAQ.DISCK',
#  'NASDAQ.DISH',
#  'NASDAQ.DLTR',
#  'NASDAQ.EA',
#  'NASDAQ.EBAY',
#  'NASDAQ.EQIX',
#  'NASDAQ.ESRX',
#  'NASDAQ.ETFC',
#  'NASDAQ.EXPD',
#  'NASDAQ.EXPE',
#  'NASDAQ.FAST',
#  'NASDAQ.FB',
#  'NASDAQ.FFIV',
#  'NASDAQ.FISV',
#  'NASDAQ.FITB',
#  'NASDAQ.FLIR',
#  'NASDAQ.FOX',
#  'NASDAQ.FOXA',
#  'NASDAQ.GILD',
#  'NASDAQ.GOOG',
#  'NASDAQ.GOOGL',
#  'NASDAQ.GRMN',
#  'NASDAQ.GT',
#  'NASDAQ.HAS',
#  'NASDAQ.HBAN',
#  'NASDAQ.HOLX',
#  'NASDAQ.HSIC',
#  'NASDAQ.IDXX',
#  'NASDAQ.ILMN',
#  'NASDAQ.INCY',
#  'NASDAQ.INFO',
#  'NASDAQ.INTC',
#  'NASDAQ.INTU',
#  'NASDAQ.ISRG',
#  'NASDAQ.JBHT',
#  'NASDAQ.KHC',
#  'NASDAQ.KLAC',
#  'NASDAQ.LKQ',
#  'NASDAQ.LRCX',
#  'NASDAQ.MAR',
#  'NASDAQ.MAT',
#  'NASDAQ.MCHP',
#  'NASDAQ.MDLZ',
#  'NASDAQ.MNST',
#  'NASDAQ.MSFT',
#  'NASDAQ.MU',
#  'NASDAQ.MYL',
#  'NASDAQ.NAVI',
#  'NASDAQ.NDAQ',
#  'NASDAQ.NFLX',
#  'NASDAQ.NTAP',
#  'NASDAQ.NTRS',
#  'NASDAQ.NVDA',
#  'NASDAQ.NWS',
#  'NASDAQ.NWSA',
#  'NASDAQ.ORLY',
#  'NASDAQ.PAYX',
#  'NASDAQ.PBCT',
#  'NASDAQ.PCAR',
#  'NASDAQ.PCLN',
#  'NASDAQ.PDCO',
#  'NASDAQ.PYPL',
#  'NASDAQ.QCOM',
#  'NASDAQ.QRVO',
#  'NASDAQ.REGN',
#  'NASDAQ.ROST',
#  'NASDAQ.SBUX',
#  'NASDAQ.SNI',
#  'NASDAQ.SNPS',
#  'NASDAQ.SPLS',
#  'NASDAQ.SRCL',
#  'NASDAQ.STX',
#  'NASDAQ.SWKS',
#  'NASDAQ.SYMC',
#  'NASDAQ.TRIP',
#  'NASDAQ.TROW',
#  'NASDAQ.TSCO',
#  'NASDAQ.TXN',
#  'NASDAQ.ULTA',
#  'NASDAQ.VIAB',
#  'NASDAQ.VRSK',
#  'NASDAQ.VRSN',
#  'NASDAQ.VRTX',
#  'NASDAQ.WBA',
#  'NASDAQ.WDC',
#  'NASDAQ.WFM',
#  'NASDAQ.WLTW',
#  'NASDAQ.WYNN',
#  'NASDAQ.XLNX',
#  'NASDAQ.XRAY',
#  'NASDAQ.ZION',
#  'NYSE.A',
#  'NYSE.AAP',
#  'NYSE.ABBV',
#  'NYSE.ABC',
#  'NYSE.ABT',
#  'NYSE.ACN',
#  'NYSE.ADM',
#  'NYSE.ADS',
#  'NYSE.AEE',
#  'NYSE.AEP',
#  'NYSE.AES',
#  'NYSE.AET',
#  'NYSE.AFL',
#  'NYSE.AGN',
#  'NYSE.AIG',
#  'NYSE.AIV',
#  'NYSE.AIZ',
#  'NYSE.AJG',
#  'NYSE.ALB',
#  'NYSE.ALK',
#  'NYSE.ALL',
#  'NYSE.ALLE',
#  'NYSE.AME',
#  'NYSE.AMG',
#  'NYSE.AMP',
#  'NYSE.AMT',
#  'NYSE.AN',
#  'NYSE.ANTM',
#  'NYSE.AON',
#  'NYSE.APA',
#  'NYSE.APC',
#  'NYSE.APD',
#  'NYSE.APH',
#  'NYSE.ARE',
#  'NYSE.ARNC',
#  'NYSE.AVB',
#  'NYSE.AVY',
#  'NYSE.AWK',
#  'NYSE.AXP',
#  'NYSE.AYI',
#  'NYSE.AZO',
#  'NYSE.BA',
#  'NYSE.BAC',
#  'NYSE.BAX',
#  'NYSE.BBT',
#  'NYSE.BBY',
#  'NYSE.BCR',
#  'NYSE.BDX',
#  'NYSE.BEN',
#  'NYSE.BF.B',
#  'NYSE.BHI',
#  'NYSE.BK',
#  'NYSE.BLK',
#  'NYSE.BLL',
#  'NYSE.BMY',
#  'NYSE.BRK.B',
#  'NYSE.BSX',
#  'NYSE.BWA',
#  'NYSE.BXP',
#  'NYSE.C',
#  'NYSE.CAG',
#  'NYSE.CAH',
#  'NYSE.CAT',
#  'NYSE.CB',
#  'NYSE.CBG',
#  'NYSE.CBS',
#  'NYSE.CCI',
#  'NYSE.CCL',
#  'NYSE.CF',
#  'NYSE.CFG',
#  'NYSE.CHD',
#  'NYSE.CHK',
#  'NYSE.CI',
#  'NYSE.CL',
#  'NYSE.CLX',
#  'NYSE.CMA',
#  'NYSE.CMG',
#  'NYSE.CMI',
#  'NYSE.CMS',
#  'NYSE.CNC',
#  'NYSE.CNP',
#  'NYSE.COF',
#  'NYSE.COG',
#  'NYSE.COH',
#  'NYSE.COL',
#  'NYSE.COO',
#  'NYSE.COP',
#  'NYSE.COTY',
#  'NYSE.CPB',
#  'NYSE.CRM',
#  'NYSE.CSRA',
#  'NYSE.CTL',
#  'NYSE.CVS',
#  'NYSE.CVX',
#  'NYSE.CXO',
#  'NYSE.D',
#  'NYSE.DAL',
#  'NYSE.DD',
#  'NYSE.DE',
#  'NYSE.DFS',
#  'NYSE.DG',
#  'NYSE.DGX',
#  'NYSE.DHI',
#  'NYSE.DHR',
#  'NYSE.DIS',
#  'NYSE.DLPH',
#  'NYSE.DLR',
#  'NYSE.DOV',
#  'NYSE.DOW',
#  'NYSE.DPS',
#  'NYSE.DRI',
#  'NYSE.DTE',
#  'NYSE.DUK',
#  'NYSE.DVA',
#  'NYSE.DVN',
#  'NYSE.DXC',
#  'NYSE.ECL',
#  'NYSE.ED',
#  'NYSE.EFX',
#  'NYSE.EIX',
#  'NYSE.EL',
#  'NYSE.EMN',
#  'NYSE.EMR',
#  'NYSE.EOG',
#  'NYSE.EQR',
#  'NYSE.EQT',
#  'NYSE.ES',
#  'NYSE.ESS',
#  'NYSE.ETN',
#  'NYSE.ETR',
#  'NYSE.EVHC',
#  'NYSE.EW',
#  'NYSE.EXC',
#  'NYSE.EXR',
#  'NYSE.F',
#  'NYSE.FBHS',
#  'NYSE.FCX',
#  'NYSE.FDX',
#  'NYSE.FE',
#  'NYSE.FIS',
#  'NYSE.FL',
#  'NYSE.FLR',
#  'NYSE.FLS',
#  'NYSE.FMC',
#  'NYSE.FRT',
#  'NYSE.FTI',
#  'NYSE.FTV',
#  'NYSE.GD',
#  'NYSE.GE',
#  'NYSE.GGP',
#  'NYSE.GIS',
#  'NYSE.GLW',
#  'NYSE.GM',
#  'NYSE.GPC',
#  'NYSE.GPN',
#  'NYSE.GPS',
#  'NYSE.GS',
#  'NYSE.GWW',
#  'NYSE.HAL',
#  'NYSE.HBI',
#  'NYSE.HCA',
#  'NYSE.HCN',
#  'NYSE.HCP',
#  'NYSE.HD',
#  'NYSE.HES',
#  'NYSE.HIG',
#  'NYSE.HOG',
#  'NYSE.HON',
#  'NYSE.HP',
#  'NYSE.HPE',
#  'NYSE.HPQ',
#  'NYSE.HRB',
#  'NYSE.HRL',
#  'NYSE.HRS',
#  'NYSE.HST',
#  'NYSE.HSY',
#  'NYSE.HUM',
#  'NYSE.IBM',
#  'NYSE.ICE',
#  'NYSE.IFF',
#  'NYSE.IP',
#  'NYSE.IPG',
#  'NYSE.IR',
#  'NYSE.IRM',
#  'NYSE.IT',
#  'NYSE.ITW',
#  'NYSE.IVZ',
#  'NYSE.JCI',
#  'NYSE.JEC',
#  'NYSE.JNJ',
#  'NYSE.JNPR',
#  'NYSE.JPM',
#  'NYSE.JWN',
#  'NYSE.K',
#  'NYSE.KEY',
#  'NYSE.KIM',
#  'NYSE.KMB',
#  'NYSE.KMI',
#  'NYSE.KMX',
#  'NYSE.KO',
#  'NYSE.KORS',
#  'NYSE.KR',
#  'NYSE.KSS',
#  'NYSE.KSU',
#  'NYSE.L',
#  'NYSE.LB',
#  'NYSE.LEG',
#  'NYSE.LEN',
#  'NYSE.LH',
#  'NYSE.LLL',
#  'NYSE.LLY',
#  'NYSE.LMT',
#  'NYSE.LNC',
#  'NYSE.LNT',
#  'NYSE.LOW',
#  'NYSE.LUK',
#  'NYSE.LUV',
#  'NYSE.LVLT',
#  'NYSE.LYB',
#  'NYSE.M',
#  'NYSE.MA',
#  'NYSE.MAA',
#  'NYSE.MAC',
#  'NYSE.MAS',
#  'NYSE.MCD',
#  'NYSE.MCK',
#  'NYSE.MCO',
#  'NYSE.MDT',
#  'NYSE.MET',
#  'NYSE.MHK',
#  'NYSE.MKC',
#  'NYSE.MLM',
#  'NYSE.MMC',
#  'NYSE.MMM',
#  'NYSE.MNK',
#  'NYSE.MO',
#  'NYSE.MON',
#  'NYSE.MOS',
#  'NYSE.MPC',
#  'NYSE.MRK',
#  'NYSE.MRO',
#  'NYSE.MS',
#  'NYSE.MSI',
#  'NYSE.MTB',
#  'NYSE.MUR',
#  'NYSE.NBL',
#  'NYSE.NEE',
#  'NYSE.NEM',
#  'NYSE.NFX',
#  'NYSE.NI',
#  'NYSE.NKE',
#  'NYSE.NLSN',
#  'NYSE.NOC',
#  'NYSE.NOV',
#  'NYSE.NRG',
#  'NYSE.NSC',
#  'NYSE.NUE',
#  'NYSE.NWL',
#  'NYSE.O',
#  'NYSE.OKE',
#  'NYSE.OMC',
#  'NYSE.ORCL',
#  'NYSE.OXY',
#  'NYSE.PCG',
#  'NYSE.PEG',
#  'NYSE.PEP',
#  'NYSE.PFE',
#  'NYSE.PFG',
#  'NYSE.PG',
#  'NYSE.PGR',
#  'NYSE.PH',
#  'NYSE.PHM',
#  'NYSE.PKI',
#  'NYSE.PLD',
#  'NYSE.PM',
#  'NYSE.PNC',
#  'NYSE.PNR',
#  'NYSE.PNW',
#  'NYSE.PPG',
#  'NYSE.PPL',
#  'NYSE.PRGO',
#  'NYSE.PRU',
#  'NYSE.PSA',
#  'NYSE.PSX',
#  'NYSE.PVH',
#  'NYSE.PWR',
#  'NYSE.PX',
#  'NYSE.PXD',
#  'NYSE.RAI',
#  'NYSE.RCL',
#  'NYSE.REG',
#  'NYSE.RF',
#  'NYSE.RHI',
#  'NYSE.RHT',
#  'NYSE.RIG',
#  'NYSE.RJF',
#  'NYSE.RL',
#  'NYSE.ROK',
#  'NYSE.ROP',
#  'NYSE.RRC',
#  'NYSE.RSG',
#  'NYSE.RTN',
#  'NYSE.SCG',
#  'NYSE.SCHW',
#  'NYSE.SEE',
#  'NYSE.SHW',
#  'NYSE.SIG',
#  'NYSE.SJM',
#  'NYSE.SLB',
#  'NYSE.SLG',
#  'NYSE.SNA',
#  'NYSE.SO',
#  'NYSE.SPG',
#  'NYSE.SPGI',
#  'NYSE.SRE',
#  'NYSE.STI',
#  'NYSE.STT',
#  'NYSE.STZ',
#  'NYSE.SWK',
#  'NYSE.SYF',
#  'NYSE.SYK',
#  'NYSE.SYY',
#  'NYSE.T',
#  'NYSE.TAP',
#  'NYSE.TDG',
#  'NYSE.TEL',
#  'NYSE.TGT',
#  'NYSE.TIF',
#  'NYSE.TJX',
#  'NYSE.TMK',
#  'NYSE.TMO',
#  'NYSE.TRV',
#  'NYSE.TSN',
#  'NYSE.TSO',
#  'NYSE.TSS',
#  'NYSE.TWX',
#  'NYSE.TXT',
#  'NYSE.UA',
#  'NYSE.UAA',
#  'NYSE.UAL',
#  'NYSE.UDR',
#  'NYSE.UHS',
#  'NYSE.UNH',
#  'NYSE.UNM',
#  'NYSE.UNP',
#  'NYSE.UPS',
#  'NYSE.URI',
#  'NYSE.USB',
#  'NYSE.UTX',
#  'NYSE.V',
#  'NYSE.VAR',
#  'NYSE.VFC',
#  'NYSE.VLO',
#  'NYSE.VMC',
#  'NYSE.VNO',
#  'NYSE.VTR',
#  'NYSE.VZ',
#  'NYSE.WAT',
#  'NYSE.WEC',
#  'NYSE.WFC',
#  'NYSE.WHR',
#  'NYSE.WM',
#  'NYSE.WMB',
#  'NYSE.WMT',
#  'NYSE.WRK',
#  'NYSE.WU',
#  'NYSE.WY',
#  'NYSE.WYN',
#  'NYSE.XEC',
#  'NYSE.XEL',
#  'NYSE.XL',
#  'NYSE.XOM',
#  'NYSE.XRX',
#  'NYSE.XYL',
#  'NYSE.YUM',
#  'NYSE.ZBH',
#  'NYSE.ZTS']

# %%
len(columns)
# Out:
# 502

# %% [markdown]
# # datetime examples

# %%
import datetime

# %%
 datetime.datetime.fromtimestamp(
        int("1491226200")
    ).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2017-04-03 16:30:00'

# %%
 datetime.datetime.fromtimestamp(
        int("1531469800")
    ).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2018-07-13 11:16:40'

# %%
 datetime.datetime.fromtimestamp(
        int("1491226260")
    ).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2017-04-03 16:31:00'

# %% [markdown]
# # plotting

# %%
dataset.size
# Out:
# 20674266

# %%
dataset = dataset.drop(['DATE'], 1)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(dataset['SP500'])

# %% [markdown]
# # my own dataset

# %%
import json

# %%
import requests

# %%
response = requests.get('https://www.cryptocompare.com/api/data/coinlist/')

# %%
response.text
# Out:
# '{"Response":"Success","Message":"Coin list succesfully returned! This api is moving to https://min-api.cryptocompare.com/data/all/coinlist, please change the path.","BaseImageUrl":"https://www.cryptocompare.com","BaseLinkUrl":"https://www.cryptocompare.com","DefaultWatchlist":{"CoinIs":"1182,7605,5038,24854,3807,3808,202330,5324,5031,20131","Sponsored":""},"SponosoredNews":[{"id":907274,"guid":"https://goo.gl/x2wT5k","published_on":1530020965,"imageurl":"https://www.cryptocompare.com/media/34077391/onlineio200x200.gif?anchor=center&mode=crop&width=300&height=300&rnd=131744945650000000","title":"Online.io - Earn Tokens to Browse The Internet","url":"https://goo.gl/x2wT5k","source":"CryptoCompare","body":"Online.io is implementing a decentralized ecosystem which combines all necessary features for a faster, safer, and more private Internet browsing. Moreover, through the Online.io platform developed by using the most advanced Blockchain technology, both internet end users and website operators will benefit alike.\\r\\n\\r\\nThe Online (OIO) token is a unique digital asset that will unleash the Internet from ads, malware and tracking software, leading to a more enjoyable and secure browsing experience, with sizeable benefits for both web operators and end users.","tags":"ICO","categories":"ICO","lang":"EN","source_info":{}}],"Data":{"BTC":{"Id":"1182","Url":"/coins/btc/overview","ImageUrl":"/media/19633/btc.png","Name":"BTC","Symbol":"BTC","CoinName":"Bitcoin","FullName":"Bitcoin (BTC)","Algorithm":"SHA256","ProofType":"PoW","FullyPremined":"0","TotalCoinSupply":"21000000","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"1","Sponsored":false},"ETH":{"Id":"7605","Url":"/coins/eth/overview","ImageUrl":"/media/20646/eth_logo.png","Name":"ETH","Symbol":"ETH","CoinName":"Ethereum","FullName":"Ethereum (ETH)","Algorithm":"Ethash","ProofType":"PoW","FullyPremined":"0","TotalCoinSupply":"0","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"2","Sponsored":false},"LTC":{"Id":"3808","Url":"/coins/ltc/overview","ImageUrl":"/media/19782/litecoin-logo.png","Name":"LTC","Symbol":"LTC","CoinName":"Litecoin","FullName":"Litecoin (LTC)","Algorithm":"Scrypt","ProofType":"PoW","FullyPremined":"0","TotalCoinSupply":"84000000","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"3","Sponsored":false},"DASH":{"Id":"3807","Url":"/coins/dash/overview","ImageUrl":"/media/33842920/dash.png","Name":"DASH","Symbol":"DASH","CoinName":"Dash","FullName":"Dash (DASH)","Algorithm":"X11","ProofType":"PoW/PoS","FullyPremined":"0","TotalCoinSupply":"22000000","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"4","Sponsored":false},"XMR":{"Id":"5038","Url":"/coins/xmr/overview","ImageUrl":"/media/19969/xmr.png","Name":"XMR","Symbol":"XMR","CoinName":"Monero","FullName":"Monero (XMR)","Algorithm":"CryptoNight-V7","ProofType":"PoW","FullyPremined":"0","TotalCoinSupply":"0","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"5","Sponsored":false},"NXT":{"Id":"1183","Url":"/coins/nxt/overview","ImageUrl":"/media/20627/nxt.png","Name":"NXT","Symbol":"NXT","CoinName":"Nxt","FullName":"Nxt (NXT)","Algorithm":"PoS","ProofType":"PoS/LPoS","FullyPremined":"1","TotalCoinSupply":"1000000000","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"6","Sponsored":false},"ETC":{"Id":"5324","Url":"/coins/etc/overview","ImageUrl":"/media/33752295/etc_new.png","Name":"ETC","Symbol":"ETC","CoinName":"Ethereum Classic","FullName":"Ethereum Classic (ETC)","Algorithm":"Ethash","ProofType":"PoW","FullyPremined":"0","TotalCoinSupply":"N/A","BuiltOn":"N/A","SmartContractAddress":"N/A","PreMinedValue":"N/A","TotalCoinsFreeFloat":"N/A","SortOrder":"7","Sponsored ...

# %%
coins= json.loads(response.text)

# %%
coins.keys()
# Out:
# dict_keys(['DefaultWatchlist', 'Type', 'SponosoredNews', 'BaseLinkUrl', 'Data', 'BaseImageUrl', 'Message', 'Response'])

# %%
coins['Data']
# Out:
# {'DEC': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Darico',
#   'FullName': 'Darico (DEC)',
#   'FullyPremined': '0',
#   'Id': '417510',
#   'ImageUrl': '/media/16746438/drc.png',
#   'Name': 'DEC',
#   'PreMinedValue': 'N/A',
#   'ProofType': '240000000',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1905',
#   'Sponsored': False,
#   'Symbol': 'DEC',
#   'TotalCoinSupply': '72000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/dec/overview'},
#  'PURE': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Pure',
#   'FullName': 'Pure (PURE)',
#   'FullyPremined': '0',
#   'Id': '370535',
#   'ImageUrl': '/media/14913451/pure.png',
#   'Name': 'PURE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1788',
#   'Sponsored': False,
#   'Symbol': 'PURE',
#   'TotalCoinSupply': '3686860',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/pure/overview'},
#  'COIN*': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Coin',
#   'FullName': 'Coin (COIN*)',
#   'FullyPremined': '0',
#   'Id': '20714',
#   'ImageUrl': '/media/350950/coin.png',
#   'Name': 'COIN*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '561',
#   'Sponsored': False,
#   'Symbol': 'COIN*',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/coinstar/overview'},
#  'AIB': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'AdvancedInternetBlock',
#   'FullName': 'AdvancedInternetBlock (AIB)',
#   'FullyPremined': '0',
#   'Id': '20806',
#   'ImageUrl': '/media/350971/aib.png',
#   'Name': 'AIB',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '571',
#   'Sponsored': False,
#   'Symbol': 'AIB',
#   'TotalCoinSupply': '314159265359',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/aib/overview'},
#  'XCN': {'Algorithm': 'M7 POW',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Cryptonite',
#   'FullName': 'Cryptonite (XCN)',
#   'FullyPremined': '0',
#   'Id': '5386',
#   'ImageUrl': '/media/20483/xcn.png',
#   'Name': 'XCN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '354',
#   'Sponsored': False,
#   'Symbol': 'XCN',
#   'TotalCoinSupply': '1840000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xcn/overview'},
#  'EZT': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'EZToken',
#   'FullName': 'EZToken (EZT)',
#   'FullyPremined': '0',
#   'Id': '850994',
#   'ImageUrl': '/media/30002107/ezt.jpg',
#   'Name': 'EZT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x5e6016ae7d7c49d347dcf834860b9f3ee282812b',
#   'SortOrder': '2586',
#   'Sponsored': False,
#   'Symbol': 'EZT',
#   'TotalCoinSupply': '50000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ezt/overview'},
#  'GES': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Galaxy eSolutions',
#   'FullName': 'Galaxy eSolutions (GES)',
#   'FullyPremined': '0',
#   'Id': '377508',
#   'ImageUrl': '/media/14913547/ges.png',
#   'Name': 'GES',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xfb1e5f5e984c28ad7e228cdaa1f8a0919bb6a09b',
#   'SortOrder': '1822',
#   'Sponsored': False,
#   'Symbol': 'GES',
#   'TotalCoinSupply': '300000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ges/overview'},
#  'GLD': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'GoldCoin',
#   'FullName': 'GoldCoin (GLD)',
#   'FullyPremined': '0',
#   'Id': '4528',
#   'ImageUrl': '/media/19723/gld.png',
#   'Name': 'GLD',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '124',
#   'Sponsored': False,
#   'Symbol': 'GLD',
#   'TotalCoinSupply': '72245700',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/gld/overview'},
#  'EPY': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Empyrean',
#   'FullName': 'Empyrean (EPY)',
#   'FullyPremined': '0',
#   'Id': '7564',
#   'ImageUrl': '/media/20628/epy.png',
#   'Name': 'EPY',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '424',
#   'Sponsored': False,
#   'Symbol': 'EPY',
#   'TotalCoinSupply': '100000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/epy/overview'},
#  'BEE': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Bee Token',
#   'FullName': 'Bee Token (BEE)',
#   'FullyPremined': '0',
#   'Id': '764334',
#   'ImageUrl': '/media/27010700/bee.png',
#   'Name': 'BEE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x4d8fc1453a0f359e99c9675954e656d80d996fbf',
#   'SortOrder': '2258',
#   'Sponsored': False,
#   'Symbol': 'BEE',
#   'TotalCoinSupply': '500000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bee/overview'},
#  'CLIN': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Clinicoin',
#   'FullName': 'Clinicoin (CLIN)',
#   'FullyPremined': '0',
#   'Id': '785910',
#   'ImageUrl': '/media/27010911/clin.png',
#   'Name': 'CLIN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2372',
#   'Sponsored': False,
#   'Symbol': 'CLIN',
#   'TotalCoinSupply': '3000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/clin/overview'},
#  'GUE': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'GuerillaCoin',
#   'FullName': 'GuerillaCoin (GUE)',
#   'FullyPremined': '0',
#   'Id': '4532',
#   'ImageUrl': '/media/19732/gue.png',
#   'Name': 'GUE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '128',
#   'Sponsored': False,
#   'Symbol': 'GUE',
#   'TotalCoinSupply': '19500000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/gue/overview'},
#  'BBR': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Boolberry',
#   'FullName': 'Boolberry (BBR)',
#   'FullyPremined': '0',
#   'Id': '5343',
#   'ImageUrl': '/media/19609/bbr.png',
#   'Name': 'BBR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '311',
#   'Sponsored': False,
#   'Symbol': 'BBR',
#   'TotalCoinSupply': '18450000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bbr/overview'},
#  'CRAVE': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CraveCoin',
#   'FullName': 'CraveCoin (CRAVE)',
#   'FullyPremined': '0',
#   'Id': '5304',
#   'ImageUrl': '/media/20242/crave.png',
#   'Name': 'CRAVE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '273',
#   'Sponsored': False,
#   'Symbol': 'CRAVE',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/crave/overview'},
#  'GST': {'Algorithm': 'GOST_R_3410_2012',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Gostcoin',
#   'FullName': 'Gostcoin (GST)',
#   'FullyPremined': '0',
#   'Id': '847347',
#   'ImageUrl': '/media/30002016/gst.png',
#   'Name': 'GST',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2552',
#   'Sponsored': False,
#   'Symbol': 'GST',
#   'TotalCoinSupply': '3103954',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/gst/overview'},
#  'TIX': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Blocktix',
#   'FullName': 'Blocktix (TIX)',
#   'FullyPremined': '0',
#   'Id': '175671',
#   'ImageUrl': '/media/1383690/tix.png',
#   'Name': 'TIX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xea1f346faf023f974eb5adaf088bbcdf02d761f4',
#   'SortOrder': '1285',
#   'Sponsored': False,
#   'Symbol': 'TIX',
#   'TotalCoinSupply': '62500000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/tix/overview'},
#  'CVT': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'CyberVein',
#   'FullName': 'CyberVein (CVT)',
#   'FullyPremined': '0',
#   'Id': '879044',
#   'ImageUrl': '/media/32655908/cvt.jpg',
#   'Name': 'CVT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xbe428c3867f05dea2a89fc76a102b544eac7f772',
#   'SortOrder': '2701',
#   'Sponsored': False,
#   'Symbol': 'CVT',
#   'TotalCoinSupply': '2147483648',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cvt/overview'},
#  'WPR': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'WePower',
#   'FullName': 'WePower (WPR)',
#   'FullyPremined': '0',
#   'Id': '355242',
#   'ImageUrl': '/media/14543969/wpr.png',
#   'Name': 'WPR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x4CF488387F035FF08c371515562CBa712f9015d4',
#   'SortOrder': '1752',
#   'Sponsored': False,
#   'Symbol': 'WPR',
#   'TotalCoinSupply': '746403007.29',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/wpr/overview'},
#  'LUN': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Lunyr',
#   'FullName': 'Lunyr (LUN)',
#   'FullyPremined': '0',
#   'Id': '67447',
#   'ImageUrl': '/media/1383112/lunyr-logo.png',
#   'Name': 'LUN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1188',
#   'Sponsored': False,
#   'Symbol': 'LUN',
#   'TotalCoinSupply': '2703356.0785',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/lun/overview'},
#  'NLX': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Nullex',
#   'FullName': 'Nullex (NLX)',
#   'FullyPremined': '0',
#   'Id': '892539',
#   'ImageUrl': '/media/33187915/rsz_k6egfcvp_400x400.jpg',
#   'Name': 'NLX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2762',
#   'Sponsored': False,
#   'Symbol': 'NLX',
#   'TotalCoinSupply': '50648181',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nlx/overview'},
#  'SUMO': {'Algorithm': 'CryptoNight',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Sumokoin',
#   'FullName': 'Sumokoin (SUMO)',
#   'FullyPremined': '0',
#   'Id': '310812',
#   'ImageUrl': '/media/27010696/sumo.png',
#   'Name': 'SUMO',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1599',
#   'Sponsored': False,
#   'Symbol': 'SUMO',
#   'TotalCoinSupply': '88888888',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/sumo/overview'},
#  'EBET': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'EthBet',
#   'FullName': 'EthBet (EBET)',
#   'FullyPremined': '0',
#   'Id': '345159',
#   'ImageUrl': '/media/12318358/ebet.png',
#   'Name': 'EBET',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x7D5Edcd23dAa3fB94317D32aE253eE1Af08Ba14d',
#   'SortOrder': '1719',
#   'Sponsored': False,
#   'Symbol': 'EBET',
#   'TotalCoinSupply': '10000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ebet/overview'},
#  'ZCL': {'Algorithm': 'Equihash',
#   'BuiltOn': 'N/A',
#   'CoinName': 'ZClassic',
#   'FullName': 'ZClassic (ZCL)',
#   'FullyPremined': '0',
#   'Id': '32544',
#   'ImageUrl': '/media/351926/zcl.png',
#   'Name': 'ZCL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '879',
#   'Sponsored': False,
#   'Symbol': 'ZCL',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/zcl/overview'},
#  'DLC': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'DollarCoin',
#   'FullName': 'DollarCoin (DLC)',
#   'FullyPremined': '0',
#   'Id': '28776',
#   'ImageUrl': '/media/351559/dlc.png',
#   'Name': 'DLC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '778',
#   'Sponsored': False,
#   'Symbol': 'DLC',
#   'TotalCoinSupply': '10638298',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/dlc/overview'},
#  'PF': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'PROVER',
#   'FullName': 'PROVER (PF)',
#   'FullyPremined': '0',
#   'Id': '791305',
#   'ImageUrl': '/media/27010950/untitled-1.png',
#   'Name': 'PF',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x6f3a995e904c9be5279e375e79f3c30105efa618',
#   'SortOrder': '2396',
#   'Sponsored': False,
#   'Symbol': 'PF',
#   'TotalCoinSupply': '1000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/pf/overview'},
#  'SNRG': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Synergy',
#   'FullName': 'Synergy (SNRG)',
#   'FullyPremined': '0',
#   'Id': '8825',
#   'ImageUrl': '/media/20700/snrg.png',
#   'Name': 'SNRG',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '461',
#   'Sponsored': False,
#   'Symbol': 'SNRG',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/snrg/overview'},
#  'X2': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'X2Coin',
#   'FullName': 'X2Coin (X2)',
#   'FullyPremined': '0',
#   'Id': '29376',
#   'ImageUrl': '/media/351635/x2.png',
#   'Name': 'X2',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '806',
#   'Sponsored': False,
#   'Symbol': 'X2',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/x2/overview'},
#  'ALEX': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Alexandrite',
#   'FullName': 'Alexandrite (ALEX)',
#   'FullyPremined': '0',
#   'Id': '45607',
#   'ImageUrl': '/media/1382657/alex.png',
#   'Name': 'ALEX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1100',
#   'Sponsored': False,
#   'Symbol': 'ALEX',
#   'TotalCoinSupply': '1268000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/alex/overview'},
#  'GLA': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Gladius',
#   'FullName': 'Gladius (GLA)',
#   'FullyPremined': '0',
#   'Id': '318704',
#   'ImageUrl': '/media/12318141/gla.png',
#   'Name': 'GLA',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x71d01db8d6a2fbea7f8d434599c237980c234e4c',
#   'SortOrder': '1619',
#   'Sponsored': False,
#   'Symbol': 'GLA',
#   'TotalCoinSupply': '96300000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/gla/overview'},
#  'CAG': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Change',
#   'FullName': 'Change (CAG)',
#   'FullyPremined': '0',
#   'Id': '341422',
#   'ImageUrl': '/media/25792623/cag1.png',
#   'Name': 'CAG',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x7d4b8cce0591c9044a22ee543533b72e976e36c3',
#   'SortOrder': '1712',
#   'Sponsored': False,
#   'Symbol': 'CAG',
#   'TotalCoinSupply': '79184116',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cag/overview'},
#  'BLRY': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BillaryCoin',
#   'FullName': 'BillaryCoin (BLRY)',
#   'FullyPremined': '0',
#   'Id': '20336',
#   'ImageUrl': '/media/350908/blry.png',
#   'Name': 'BLRY',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '527',
#   'Sponsored': False,
#   'Symbol': 'BLRY',
#   'TotalCoinSupply': '42000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/blry/overview'},
#  'SENSE': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Sense Token',
#   'FullName': 'Sense Token (SENSE)',
#   'FullyPremined': '0',
#   'Id': '305252',
#   'ImageUrl': '/media/12318034/sense.png',
#   'Name': 'SENSE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x6745fab6801e376cd24f03572b9c9b0d4edddccf',
#   'SortOrder': '1584',
#   'Sponsored': False,
#   'Symbol': 'SENSE',
#   'TotalCoinSupply': '1000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/sense/overview'},
#  'KBR': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Kubera Coin',
#   'FullName': 'Kubera Coin (KBR)',
#   'FullyPremined': '0',
#   'Id': '674980',
#   'ImageUrl': '/media/20780782/kbr.png',
#   'Name': 'KBR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xd5527579226e4ebc8864906e49d05d4458ccf47f',
#   'SortOrder': '2075',
#   'Sponsored': False,
#   'Symbol': 'KBR',
#   'TotalCoinSupply': '1162102077',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/kbr/overview'},
#  'MDA': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Moeda',
#   'FullName': 'Moeda (MDA)',
#   'FullyPremined': '0',
#   'Id': '341279',
#   'ImageUrl': '/media/12318340/mda.png',
#   'Name': 'MDA',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x51db5ad35c671a87207d88fc11d593ac0c8415bd',
#   'SortOrder': '1709',
#   'Sponsored': False,
#   'Symbol': 'MDA',
#   'TotalCoinSupply': '19628888',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/mda/overview'},
#  'XSTC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Safe Trade Coin',
#   'FullName': 'Safe Trade Coin (XSTC)',
#   'FullyPremined': '0',
#   'Id': '917819',
#   'ImageUrl': '/media/34477716/xstc.png',
#   'Name': 'XSTC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '3016',
#   'Sponsored': False,
#   'Symbol': 'XSTC',
#   'TotalCoinSupply': '840000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xstc/overview'},
#  'CANN': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CannabisCoin',
#   'FullName': 'CannabisCoin (CANN)',
#   'FullyPremined': '0',
#   'Id': '4407',
#   'ImageUrl': '/media/20015/cann.png',
#   'Name': 'CANN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '76',
#   'Sponsored': False,
#   'Symbol': 'CANN',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cann/overview'},
#  'EGCC': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Engine',
#   'FullName': 'Engine (EGCC)',
#   'FullyPremined': '0',
#   'Id': '918374',
#   'ImageUrl': '/media/34477732/egcc.jpg',
#   'Name': 'EGCC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xaf8a215e81faea7c180ce22b72483525121813bd',
#   'SortOrder': '3018',
#   'Sponsored': False,
#   'Symbol': 'EGCC',
#   'TotalCoinSupply': '10000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/egcc/overview'},
#  'XAI': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'SapienceCoin',
#   'FullName': 'SapienceCoin (XAI)',
#   'FullyPremined': '0',
#   'Id': '5021',
#   'ImageUrl': '/media/20071/xai.png',
#   'Name': 'XAI',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoB/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '235',
#   'Sponsored': False,
#   'Symbol': 'XAI',
#   'TotalCoinSupply': '0',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xai/overview'},
#  'SHREK': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'ShrekCoin',
#   'FullName': 'ShrekCoin (SHREK)',
#   'FullyPremined': '0',
#   'Id': '21907',
#   'ImageUrl': '/media/351048/shrek.png',
#   'Name': 'SHREK',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '633',
#   'Sponsored': False,
#   'Symbol': 'SHREK',
#   'TotalCoinSupply': '1246000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/shrek/overview'},
#  'ACC*': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Accelerator Network',
#   'FullName': 'Accelerator Network (ACC*)',
#   'FullyPremined': '0',
#   'Id': '716854',
#   'ImageUrl': '/media/27010467/acc.png',
#   'Name': 'ACC*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x13f1b7fdfbe1fc66676d56483e21b1ecb40b58e2',
#   'SortOrder': '2156',
#   'Sponsored': False,
#   'Symbol': 'ACC*',
#   'TotalCoinSupply': '336314',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/accstar/overview'},
#  'MAG**': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Maggie Token',
#   'FullName': 'Maggie Token (MAG**)',
#   'FullyPremined': '0',
#   'Id': '778961',
#   'ImageUrl': '/media/27010851/mag.png',
#   'Name': 'MAG**',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x647f274b3a7248d6cf51b35f08e7e7fd6edfb271',
#   'SortOrder': '2337',
#   'Sponsored': False,
#   'Symbol': 'MAG**',
#   'TotalCoinSupply': '3200000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/magstarstar/overview'},
#  'PCS': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Pabyosi Coin',
#   'FullName': 'Pabyosi Coin (PCS)',
#   'FullyPremined': '0',
#   'Id': '32686',
#   'ImageUrl': '/media/351927/pabyosi.png',
#   'Name': 'PCS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '881',
#   'Sponsored': False,
#   'Symbol': 'PCS',
#   'TotalCoinSupply': '31500000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/pcs/overview'},
#  'RKC': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Royal Kingdom Coin',
#   'FullName': 'Royal Kingdom Coin (RKC)',
#   'FullyPremined': '1',
#   'Id': '194924',
#   'ImageUrl': '/media/1383852/rkc.png',
#   'Name': 'RKC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x6ccb56947ea1d6efdc81acfbacd8263ddfa9b202',
#   'SortOrder': '1386',
#   'Sponsored': False,
#   'Symbol': 'RKC',
#   'TotalCoinSupply': '15000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/rkc/overview'},
#  'CS': {'Algorithm': 'DPoS',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CryptoSpots',
#   'FullName': 'CryptoSpots (CS)',
#   'FullyPremined': '0',
#   'Id': '35813',
#   'ImageUrl': '/media/352292/cs.png',
#   'Name': 'CS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'DPoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '969',
#   'Sponsored': False,
#   'Symbol': 'CS',
#   'TotalCoinSupply': '5000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cs/overview'},
#  'FREC': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Freyrchain',
#   'FullName': 'Freyrchain (FREC)',
#   'FullyPremined': '0',
#   'Id': '918380',
#   'ImageUrl': '/media/34477733/frec.jpg',
#   'Name': 'FREC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x17e67d1cb4e349b9ca4bc3e17c7df2a397a7bb64',
#   'SortOrder': '3019',
#   'Sponsored': False,
#   'Symbol': 'FREC',
#   'TotalCoinSupply': '10000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/frec/overview'},
#  'SUB': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Substratum Network',
#   'FullName': 'Substratum Network (SUB)',
#   'FullyPremined': '0',
#   'Id': '221463',
#   'ImageUrl': '/media/1384011/sub1.png',
#   'Name': 'SUB',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x12480e24eb5bec1a9d4369cab6a80cad3c0a377a',
#   'SortOrder': '1457',
#   'Sponsored': False,
#   'Symbol': 'SUB',
#   'TotalCoinSupply': '600000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/sub/overview'},
#  'SKB': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'SkullBuzz',
#   'FullName': 'SkullBuzz (SKB)',
#   'FullyPremined': '0',
#   'Id': '6099',
#   'ImageUrl': '/media/19808/mrs.png',
#   'Name': 'SKB',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '386',
#   'Sponsored': False,
#   'Symbol': 'SKB',
#   'TotalCoinSupply': '0',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/skb/overview'},
#  'INSUR': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'InsurChain Coin',
#   'FullName': 'InsurChain Coin (INSUR)',
#   'FullyPremined': '0',
#   'Id': '917238',
#   'ImageUrl': '/media/34333428/insur.jpg',
#   'Name': 'INSUR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x6ea6531b603f270d23d9edd2d8279135dc5d6773',
#   'SortOrder': '3007',
#   'Sponsored': False,
#   'Symbol': 'INSUR',
#   'TotalCoinSupply': '20000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/insur/overview'},
#  'LCK': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Luckbox',
#   'FullName': 'Luckbox (LCK)',
#   'FullyPremined': '0',
#   'Id': '680484',
#   'ImageUrl': '/media/20780805/luck.png',
#   'Name': 'LCK',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2091',
#   'Sponsored': False,
#   'Symbol': 'LCK',
#   'TotalCoinSupply': '600000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/lck/overview'},
#  'APX': {'Algorithm': 'N/A',
#   'BuiltOn': '28652',
#   'CoinName': 'Apx',
#   'FullName': 'Apx (APX)',
#   'FullyPremined': '0',
#   'Id': '74912',
#   'ImageUrl': '/media/1383235/apx.png',
#   'Name': 'APX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1208',
#   'Sponsored': False,
#   'Symbol': 'APX',
#   'TotalCoinSupply': '1000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/apx/overview'},
#  'ELTCOIN': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'ELTCOIN',
#   'FullName': 'ELTCOIN (ELTCOIN)',
#   'FullyPremined': '0',
#   'Id': '438867',
#   'ImageUrl': '/media/16746556/eltcoin.png',
#   'Name': 'ELTCOIN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x44197a4c44d6a059297caf6be4f7e172bd56caaf',
#   'SortOrder': '1934',
#   'Sponsored': False,
#   'Symbol': 'ELTCOIN',
#   'TotalCoinSupply': '100000000 ',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/eltcoin/overview'},
#  'BTH': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Bytether\u200a',
#   'FullName': 'Bytether\u200a (BTH)',
#   'FullyPremined': '0',
#   'Id': '620037',
#   'ImageUrl': '/media/20780656/bth.png',
#   'Name': 'BTH',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xfad572db566e5234ac9fc3d570c4edc0050eaa92',
#   'SortOrder': '2029',
#   'Sponsored': False,
#   'Symbol': 'BTH',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bth/overview'},
#  'MOON': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'MoonCoin',
#   'FullName': 'MoonCoin (MOON)',
#   'FullyPremined': '0',
#   'Id': '4346',
#   'ImageUrl': '/media/19802/moon.png',
#   'Name': 'MOON',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '59',
#   'Sponsored': False,
#   'Symbol': 'MOON',
#   'TotalCoinSupply': '384000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/moon/overview'},
#  'R': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Revain',
#   'FullName': 'Revain (R)',
#   'FullyPremined': '0',
#   'Id': '345420',
#   'ImageUrl': '/media/12318360/r.png',
#   'Name': 'R',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x48f775efbe4f5ece6e0df2f7b5932df56823b990',
#   'SortOrder': '1720',
#   'Sponsored': False,
#   'Symbol': 'R',
#   'TotalCoinSupply': '1000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/r/overview'},
#  'UTC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'UltraCoin',
#   'FullName': 'UltraCoin (UTC)',
#   'FullyPremined': '0',
#   'Id': '5012',
#   'ImageUrl': '/media/19942/utc.png',
#   'Name': 'UTC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '226',
#   'Sponsored': False,
#   'Symbol': 'UTC',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/utc/overview'},
#  'IFC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Infinite Coin',
#   'FullName': 'Infinite Coin (IFC)',
#   'FullyPremined': '0',
#   'Id': '4539',
#   'ImageUrl': '/media/19754/ifc.png',
#   'Name': 'IFC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '135',
#   'Sponsored': False,
#   'Symbol': 'IFC',
#   'TotalCoinSupply': '9060000000000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ifc/overview'},
#  'XVE': {'Algorithm': 'PoS',
#   'BuiltOn': 'N/A',
#   'CoinName': 'The Vegan Initiative',
#   'FullName': 'The Vegan Initiative (XVE)',
#   'FullyPremined': '0',
#   'Id': '59973',
#   'ImageUrl': '/media/1382937/xve.png',
#   'Name': 'XVE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1158',
#   'Sponsored': False,
#   'Symbol': 'XVE',
#   'TotalCoinSupply': '50000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xve/overview'},
#  'QWARK': {'Algorithm': 'N/A',
#   'BuiltOn': '28652',
#   'CoinName': 'Qwark',
#   'FullName': 'Qwark (QWARK)',
#   'FullyPremined': '0',
#   'Id': '116425',
#   'ImageUrl': '/media/1383522/qwark.png',
#   'Name': 'QWARK',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1246',
#   'Sponsored': False,
#   'Symbol': 'QWARK',
#   'TotalCoinSupply': '250377576',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/qwark/overview'},
#  'TAT': {'Algorithm': 'N/A',
#   'BuiltOn': '5292',
#   'CoinName': 'Tatiana Coin',
#   'FullName': 'Tatiana Coin (TAT)',
#   'FullyPremined': '0',
#   'Id': '43933',
#   'ImageUrl': '/media/1382594/tat.png',
#   'Name': 'TAT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1079',
#   'Sponsored': False,
#   'Symbol': 'TAT',
#   'TotalCoinSupply': '3000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/tat/overview'},
#  'AVL': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Avalanche',
#   'FullName': 'Avalanche (AVL)',
#   'FullyPremined': '0',
#   'Id': '863166',
#   'ImageUrl': '/media/30002245/avl.jpg',
#   'Name': 'AVL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x2771Ef07dEfB079C309542E11219D97B562ab6b0',
#   'SortOrder': '2635',
#   'Sponsored': False,
#   'Symbol': 'AVL',
#   'TotalCoinSupply': '1000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/avl/overview'},
#  'DAC': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'DACash',
#   'FullName': 'DACash (DAC)',
#   'FullyPremined': '0',
#   'Id': '915449',
#   'ImageUrl': '/media/34155608/dac.jpg',
#   'Name': 'DAC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2989',
#   'Sponsored': False,
#   'Symbol': 'DAC',
#   'TotalCoinSupply': '50000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/dac/overview'},
#  'NEXO': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'NEXO',
#   'FullName': 'NEXO (NEXO)',
#   'FullyPremined': '0',
#   'Id': '877073',
#   'ImageUrl': '/media/32655865/nexo.jpg',
#   'Name': 'NEXO',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206',
#   'SortOrder': '2686',
#   'Sponsored': False,
#   'Symbol': 'NEXO',
#   'TotalCoinSupply': '1000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nexo/overview'},
#  'BXT': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BitTokens',
#   'FullName': 'BitTokens (BXT)',
#   'FullyPremined': '0',
#   'Id': '28208',
#   'ImageUrl': '/media/351509/bxt.png',
#   'Name': 'BXT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '746',
#   'Sponsored': False,
#   'Symbol': 'BXT',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bxt/overview'},
#  'POE': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Po.et',
#   'FullName': 'Po.et (POE)',
#   'FullyPremined': '0',
#   'Id': '188811',
#   'ImageUrl': '/media/1383828/poe.png',
#   'Name': 'POE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x0e0989b1f9b8a38983c2ba8053269ca62ec9b195',
#   'SortOrder': '1373',
#   'Sponsored': False,
#   'Symbol': 'POE',
#   'TotalCoinSupply': '3141592653',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/poe/overview'},
#  'INDI': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'IndiCoin',
#   'FullName': 'IndiCoin (INDI)',
#   'FullyPremined': '0',
#   'Id': '351078',
#   'ImageUrl': '/media/12318419/indi.png',
#   'Name': 'INDI',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': '0x0ffAB58EA5A71CC3cA40217706C3C401407fA4a8',
#   'SortOrder': '1745',
#   'Sponsored': False,
#   'Symbol': 'INDI',
#   'TotalCoinSupply': '550000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/indi/overview'},
#  'FIRE': {'Algorithm': 'X15',
#   'BuiltOn': 'N/A',
#   'CoinName': 'FireCoin',
#   'FullName': 'FireCoin (FIRE)',
#   'FullyPremined': '0',
#   'Id': '29196',
#   'ImageUrl': '/media/351625/fire.png',
#   'Name': 'FIRE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '797',
#   'Sponsored': False,
#   'Symbol': 'FIRE',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/fire/overview'},
#  'AION': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Aion',
#   'FullName': 'Aion (AION)',
#   'FullyPremined': '0',
#   'Id': '431235',
#   'ImageUrl': '/media/16746538/aion.png',
#   'Name': 'AION',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1925',
#   'Sponsored': False,
#   'Symbol': 'AION',
#   'TotalCoinSupply': '465934586.66',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/aion/overview'},
#  'NIX': {'Algorithm': 'Lyra2REv2',
#   'BuiltOn': 'N/A',
#   'CoinName': 'NIX',
#   'FullName': 'NIX (NIX)',
#   'FullyPremined': '0',
#   'Id': '917249',
#   'ImageUrl': '/media/34333430/nix.jpg',
#   'Name': 'NIX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '3008',
#   'Sponsored': False,
#   'Symbol': 'NIX',
#   'TotalCoinSupply': '175000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nix/overview'},
#  'FOPA': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Fopacoin',
#   'FullName': 'Fopacoin (FOPA)',
#   'FullyPremined': '0',
#   'Id': '903282',
#   'ImageUrl': '/media/33842947/fopa.jpg',
#   'Name': 'FOPA',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x319b33456aa1248cC0E04B555c63c10B51423A5E',
#   'SortOrder': '2846',
#   'Sponsored': False,
#   'Symbol': 'FOPA',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/fopa/overview'},
#  'HLC': {'Algorithm': 'N/A',
#   'BuiltOn': '112392',
#   'CoinName': 'Halal-Chain',
#   'FullName': 'Halal-Chain (HLC)',
#   'FullyPremined': '0',
#   'Id': '749620',
#   'ImageUrl': '/media/27010592/hlc_logo.png',
#   'Name': 'HLC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2210',
#   'Sponsored': False,
#   'Symbol': 'HLC',
#   'TotalCoinSupply': ' 1000000000000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/hlc/overview'},
#  'XCR': {'Algorithm': 'Multiple',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Crypti',
#   'FullName': 'Crypti (XCR)',
#   'FullyPremined': '0',
#   'Id': '5026',
#   'ImageUrl': '/media/19710/frac.png',
#   'Name': 'XCR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '239',
#   'Sponsored': False,
#   'Symbol': 'XCR',
#   'TotalCoinSupply': '0',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xcr/overview'},
#  'FSN': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Fusion',
#   'FullName': 'Fusion (FSN)',
#   'FullyPremined': '0',
#   'Id': '768219',
#   'ImageUrl': '/media/27010765/fsn.png',
#   'Name': 'FSN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xd0352a019e9ab9d757776f532377aaebd36fd541',
#   'SortOrder': '2283',
#   'Sponsored': False,
#   'Symbol': 'FSN',
#   'TotalCoinSupply': '57344000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/fsn/overview'},
#  'RPM': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Render Payment',
#   'FullName': 'Render Payment (RPM)',
#   'FullyPremined': '0',
#   'Id': '917365',
#   'ImageUrl': '/media/34333441/rpm.jpg',
#   'Name': 'RPM',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x9e71dab82c3a97567f0d4977e94252bdc680d0e7',
#   'SortOrder': '3011',
#   'Sponsored': False,
#   'Symbol': 'RPM',
#   'TotalCoinSupply': '1000000010',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/rpm/overview'},
#  'BTPL': {'Algorithm': 'Skein',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Bitcoin Planet',
#   'FullName': 'Bitcoin Planet (BTPL)',
#   'FullyPremined': '0',
#   'Id': '182346',
#   'ImageUrl': '/media/1383774/btpl.png',
#   'Name': 'BTPL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1332',
#   'Sponsored': False,
#   'Symbol': 'BTPL',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/btpl/overview'},
#  'NCT': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'PolySwarm',
#   'FullName': 'PolySwarm (NCT)',
#   'FullyPremined': '0',
#   'Id': '864038',
#   'ImageUrl': '/media/30002262/nct.png',
#   'Name': 'NCT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x9e46a38f5daabe8683e10793b06749eef7d733d1',
#   'SortOrder': '2642',
#   'Sponsored': False,
#   'Symbol': 'NCT',
#   'TotalCoinSupply': '1885913076',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nct/overview'},
#  'NPXS': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Pundi X',
#   'FullName': 'Pundi X (NPXS)',
#   'FullyPremined': '0',
#   'Id': '731516',
#   'ImageUrl': '/media/27010505/pxs.png',
#   'Name': 'NPXS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3',
#   'SortOrder': '2178',
#   'Sponsored': False,
#   'Symbol': 'NPXS',
#   'TotalCoinSupply': '45828700875.992774',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/npxs/overview'},
#  'VLD': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Valid',
#   'FullName': 'Valid (VLD)',
#   'FullyPremined': '0',
#   'Id': '856890',
#   'ImageUrl': '/media/30002154/vld.jpg',
#   'Name': 'VLD',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x922ac473a3cc241fd3a0049ed14536452d58d73c',
#   'SortOrder': '2602',
#   'Sponsored': False,
#   'Symbol': 'VLD',
#   'TotalCoinSupply': '1000000000 ',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/vld/overview'},
#  'LEDU': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Education Ecosystem',
#   'FullName': 'Education Ecosystem (LEDU)',
#   'FullyPremined': '0',
#   'Id': '831932',
#   'ImageUrl': '/media/30001836/ledu.png',
#   'Name': 'LEDU',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x5b26c5d0772e5bbac8b3182ae9a13f9bb2d03765',
#   'SortOrder': '2496',
#   'Sponsored': False,
#   'Symbol': 'LEDU',
#   'TotalCoinSupply': '362983094.30186835',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ledu/overview'},
#  'TIG': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Tigereum',
#   'FullName': 'Tigereum (TIG)',
#   'FullyPremined': '0',
#   'Id': '765383',
#   'ImageUrl': '/media/27010719/tig.png',
#   'Name': 'TIG',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xeee2d00eb7deb8dd6924187f5aa3496b7d06e62a',
#   'SortOrder': '2260',
#   'Sponsored': False,
#   'Symbol': 'TIG',
#   'TotalCoinSupply': '12563793.7023484698469',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/tig/overview'},
#  'CXT': {'Algorithm': 'NIST5',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Coinonat',
#   'FullName': 'Coinonat (CXT)',
#   'FullyPremined': '0',
#   'Id': '63308',
#   'ImageUrl': '/media/1383080/cxt.png',
#   'Name': 'CXT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1179',
#   'Sponsored': False,
#   'Symbol': 'CXT',
#   'TotalCoinSupply': '48252000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cxt/overview'},
#  'BBCC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BaseballCardCoin',
#   'FullName': 'BaseballCardCoin (BBCC)',
#   'FullyPremined': '0',
#   'Id': '29554',
#   'ImageUrl': '/media/351658/bbcc.png',
#   'Name': 'BBCC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '813',
#   'Sponsored': False,
#   'Symbol': 'BBCC',
#   'TotalCoinSupply': '19000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bbcc/overview'},
#  'BCR*': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Bitcoin Royal',
#   'FullName': 'Bitcoin Royal (BCR*)',
#   'FullyPremined': '1',
#   'Id': '784396',
#   'ImageUrl': '/media/27010899/bcr.jpg',
#   'Name': 'BCR*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x633a8f8e557702039463f9f2eb20b7936fff8c05',
#   'SortOrder': '2364',
#   'Sponsored': False,
#   'Symbol': 'BCR*',
#   'TotalCoinSupply': '7200000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bcrstar/overview'},
#  'IXT': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'iXledger',
#   'FullName': 'iXledger (IXT)',
#   'FullyPremined': '0',
#   'Id': '141171',
#   'ImageUrl': '/media/1383612/ixt.png',
#   'Name': 'IXT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xfca47962d45adfdfd1ab2d972315db4ce7ccf094',
#   'SortOrder': '1267',
#   'Sponsored': False,
#   'Symbol': 'IXT',
#   'TotalCoinSupply': '65778843.8311',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ixt/overview'},
#  'BITSILVER': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'bitSilver',
#   'FullName': 'bitSilver (BITSILVER)',
#   'FullyPremined': '0',
#   'Id': '892415',
#   'ImageUrl': '/media/33187928/bitgold.png',
#   'Name': 'BITSILVER',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2758',
#   'Sponsored': False,
#   'Symbol': 'BITSILVER',
#   'TotalCoinSupply': '100000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bitsilver/overview'},
#  'TKN*': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'TrollTokens',
#   'FullName': 'TrollTokens (TKN*)',
#   'FullyPremined': '0',
#   'Id': '22458',
#   'ImageUrl': '/media/351104/tkn.png',
#   'Name': 'TKN*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '674',
#   'Sponsored': False,
#   'Symbol': 'TKN*',
#   'TotalCoinSupply': '860000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/tknstar/overview'},
#  'CIN': {'Algorithm': 'Multiple',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CinderCoin',
#   'FullName': 'CinderCoin (CIN)',
#   'FullyPremined': '0',
#   'Id': '4413',
#   'ImageUrl': '/media/20698/cinder.png',
#   'Name': 'CIN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '82',
#   'Sponsored': False,
#   'Symbol': 'CIN',
#   'TotalCoinSupply': '114000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cin/overview'},
#  'SPR': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Spreadcoin',
#   'FullName': 'Spreadcoin (SPR)',
#   'FullyPremined': '0',
#   'Id': '3649',
#   'ImageUrl': '/media/20438/spr.png',
#   'Name': 'SPR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '29',
#   'Sponsored': False,
#   'Symbol': 'SPR',
#   'TotalCoinSupply': '20000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/spr/overview'},
#  'LFC': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BigLifeCoin',
#   'FullName': 'BigLifeCoin (LFC)',
#   'FullyPremined': '0',
#   'Id': '30388',
#   'ImageUrl': '/media/351757/lfc.png',
#   'Name': 'LFC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '857',
#   'Sponsored': False,
#   'Symbol': 'LFC',
#   'TotalCoinSupply': '9900000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/lfc/overview'},
#  'BUK': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CryptoBuk',
#   'FullName': 'CryptoBuk (BUK)',
#   'FullyPremined': '0',
#   'Id': '4404',
#   'ImageUrl': '/media/19637/buk.png',
#   'Name': 'BUK',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '74',
#   'Sponsored': False,
#   'Symbol': 'BUK',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/buk/overview'},
#  'OMC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'OmniCron',
#   'FullName': 'OmniCron (OMC)',
#   'FullyPremined': '0',
#   'Id': '5365',
#   'ImageUrl': '/media/1381967/omc.png',
#   'Name': 'OMC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '333',
#   'Sponsored': False,
#   'Symbol': 'OMC',
#   'TotalCoinSupply': '3371337',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/omc/overview'},
#  'MWC': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'MultiWallet Coin',
#   'FullName': 'MultiWallet Coin (MWC)',
#   'FullyPremined': '0',
#   'Id': '6107',
#   'ImageUrl': '/media/19808/mrs.png',
#   'Name': 'MWC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '394',
#   'Sponsored': False,
#   'Symbol': 'MWC',
#   'TotalCoinSupply': '0',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/mwc/overview'},
#  'AOA': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Aurora ',
#   'FullName': 'Aurora  (AOA)',
#   'FullyPremined': '0',
#   'Id': '918501',
#   'ImageUrl': '/media/34477737/aoa.jpg',
#   'Name': 'AOA',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x9ab165d795019b6d8b3e971dda91071421305e5a',
#   'SortOrder': '3022',
#   'Sponsored': False,
#   'Symbol': 'AOA',
#   'TotalCoinSupply': '10000000000 ',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/aoa/overview'},
#  'ZNE': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'ZoneCoin',
#   'FullName': 'ZoneCoin (ZNE)',
#   'FullyPremined': '0',
#   'Id': '28227',
#   'ImageUrl': '/media/351515/zne.jpg',
#   'Name': 'ZNE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '752',
#   'Sponsored': False,
#   'Symbol': 'ZNE',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/zne/overview'},
#  'XUP': {'Algorithm': 'X13',
#   'BuiltOn': 'N/A',
#   'CoinName': 'UPcoin',
#   'FullName': 'UPcoin (XUP)',
#   'FullyPremined': '0',
#   'Id': '29460',
#   'ImageUrl': '/media/351638/xup.png',
#   'Name': 'XUP',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '810',
#   'Sponsored': False,
#   'Symbol': 'XUP',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xup/overview'},
#  'ZNY': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BitZeny',
#   'FullName': 'BitZeny (ZNY)',
#   'FullyPremined': '0',
#   'Id': '8762',
#   'ImageUrl': '/media/20691/zny.png',
#   'Name': 'ZNY',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '457',
#   'Sponsored': False,
#   'Symbol': 'ZNY',
#   'TotalCoinSupply': '250000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/zny/overview'},
#  'GROW': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'GrownCoin',
#   'FullName': 'GrownCoin (GROW)',
#   'FullyPremined': '0',
#   'Id': '20600',
#   'ImageUrl': '/media/350934/grow.png',
#   'Name': 'GROW',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '544',
#   'Sponsored': False,
#   'Symbol': 'GROW',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/grow/overview'},
#  'BIX': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'BiboxCoin',
#   'FullName': 'BiboxCoin (BIX)',
#   'FullyPremined': '0',
#   'Id': '757969',
#   'ImageUrl': '/media/27010664/bix.png',
#   'Name': 'BIX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xb3104b4b9da82025e8b9f8fb28b3553ce2f67069',
#   'SortOrder': '2240',
#   'Sponsored': False,
#   'Symbol': 'BIX',
#   'TotalCoinSupply': '271520349.0486829755655',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bix/overview'},
#  'CLR': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CopperLark',
#   'FullName': 'CopperLark (CLR)',
#   'FullyPremined': '0',
#   'Id': '4418',
#   'ImageUrl': '/media/19657/clr.png',
#   'Name': 'CLR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '87',
#   'Sponsored': False,
#   'Symbol': 'CLR',
#   'TotalCoinSupply': '27200000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/clr/overview'},
#  'MINE': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Instamine Nuggets',
#   'FullName': 'Instamine Nuggets (MINE)',
#   'FullyPremined': '0',
#   'Id': '5379',
#   'ImageUrl': '/media/20356/mine.png',
#   'Name': 'MINE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '347',
#   'Sponsored': False,
#   'Symbol': 'MINE',
#   'TotalCoinSupply': '21649485',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/mine/overview'},
#  'VULC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Vulcano',
#   'FullName': 'Vulcano (VULC)',
#   'FullyPremined': '0',
#   'Id': '777717',
#   'ImageUrl': '/media/27010840/vulc.jpg',
#   'Name': 'VULC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS/PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2332',
#   'Sponsored': False,
#   'Symbol': 'VULC',
#   'TotalCoinSupply': '12000000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/vulc/overview'},
#  'CNO': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Coino',
#   'FullName': 'Coino (CNO)',
#   'FullyPremined': '0',
#   'Id': '42438',
#   'ImageUrl': '/media/1382391/coino.png',
#   'Name': 'CNO',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1053',
#   'Sponsored': False,
#   'Symbol': 'CNO',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cno/overview'},
#  'WRC*': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'WarCoin',
#   'FullName': 'WarCoin (WRC*)',
#   'FullyPremined': '0',
#   'Id': '71873',
#   'ImageUrl': '/media/1383162/wrc.png',
#   'Name': 'WRC*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
# ...
#   'FullyPremined': '0',
#   'Id': '563196',
#   'ImageUrl': '/media/20780593/hat.png',
#   'Name': 'HAT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xc3972ac283b3a7a56125674631a5c254f7f373cf',
#   'SortOrder': '1999',
#   'Sponsored': False,
#   'Symbol': 'HAT',
#   'TotalCoinSupply': '7000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/hat/overview'},
#  'UNIQ': {'Algorithm': 'SHA256D',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Uniqredit',
#   'FullName': 'Uniqredit (UNIQ)',
#   'FullyPremined': '0',
#   'Id': '25594',
#   'ImageUrl': '/media/351387/uniq.png',
#   'Name': 'UNIQ',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '700',
#   'Sponsored': False,
#   'Symbol': 'UNIQ',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/uniq/overview'},
#  'OYS': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Oyster Platform',
#   'FullName': 'Oyster Platform (OYS)',
#   'FullyPremined': '0',
#   'Id': '914795',
#   'ImageUrl': '/media/34155584/oys.jpg',
#   'Name': 'OYS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2976',
#   'Sponsored': False,
#   'Symbol': 'OYS',
#   'TotalCoinSupply': '25000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/oys/overview'},
#  'XCS': {'Algorithm': 'POS 3.0',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CybCSec Coin',
#   'FullName': 'CybCSec Coin (XCS)',
#   'FullyPremined': '0',
#   'Id': '340112',
#   'ImageUrl': '/media/12318323/xcs.png',
#   'Name': 'XCS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1698',
#   'Sponsored': False,
#   'Symbol': 'XCS',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/xcs/overview'},
#  'CPAY': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'CryptoPay',
#   'FullName': 'CryptoPay (CPAY)',
#   'FullyPremined': '0',
#   'Id': '345674',
#   'ImageUrl': '/media/12318303/cpay.png',
#   'Name': 'CPAY',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x0ebb614204e47c09b6c3feb9aaecad8ee060e23e',
#   'SortOrder': '1723',
#   'Sponsored': False,
#   'Symbol': 'CPAY',
#   'TotalCoinSupply': '320000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cpay/overview'},
#  'BTM*': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Bytom',
#   'FullName': 'Bytom (BTM*)',
#   'FullyPremined': '0',
#   'Id': '218008',
#   'ImageUrl': '/media/1383996/btm.png',
#   'Name': 'BTM*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xcb97e65f07da24d46bcdd078ebebd7c6e6e3d750',
#   'SortOrder': '1450',
#   'Sponsored': False,
#   'Symbol': 'BTM*',
#   'TotalCoinSupply': '1407000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/btmstar/overview'},
#  'HTC': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Hitcoin',
#   'FullName': 'Hitcoin (HTC)',
#   'FullyPremined': '0',
#   'Id': '20153',
#   'ImageUrl': '/media/350888/htc.png',
#   'Name': 'HTC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '508',
#   'Sponsored': False,
#   'Symbol': 'HTC',
#   'TotalCoinSupply': '26550000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/htc/overview'},
#  'NIHL': {'Algorithm': 'NeoScrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Nihilo Coin',
#   'FullName': 'Nihilo Coin (NIHL)',
#   'FullyPremined': '0',
#   'Id': '789789',
#   'ImageUrl': '/media/27010943/nihl.png',
#   'Name': 'NIHL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2387',
#   'Sponsored': False,
#   'Symbol': 'NIHL',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nihl/overview'},
#  'ZEN*': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Zen Protocol',
#   'FullName': 'Zen Protocol (ZEN*)',
#   'FullyPremined': '0',
#   'Id': '586160',
#   'ImageUrl': '/media/20780609/zen.png',
#   'Name': 'ZEN*',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2004',
#   'Sponsored': False,
#   'Symbol': 'ZEN*',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/zenstar/overview'},
#  'PIGGY': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Piggy Coin',
#   'FullName': 'Piggy Coin (PIGGY)',
#   'FullyPremined': '0',
#   'Id': '7577',
#   'ImageUrl': '/media/19854/piggy.png',
#   'Name': 'PIGGY',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '427',
#   'Sponsored': False,
#   'Symbol': 'PIGGY',
#   'TotalCoinSupply': '0',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/piggy/overview'},
#  'CHIPS*': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'CHIPS',
#   'FullName': 'CHIPS (CHIPS)',
#   'FullyPremined': '0',
#   'Id': '517603',
#   'ImageUrl': '/media/16746673/chips.png',
#   'Name': 'CHIPS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1977',
#   'Sponsored': False,
#   'Symbol': 'CHIPS*',
#   'TotalCoinSupply': '21000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/chips/overview'},
#  'PHC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Profit Hunters Coin',
#   'FullName': 'Profit Hunters Coin (PHC)',
#   'FullyPremined': '0',
#   'Id': '860938',
#   'ImageUrl': '/media/30002220/phc.jpg',
#   'Name': 'PHC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2622',
#   'Sponsored': False,
#   'Symbol': 'PHC',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/phc/overview'},
#  'HYDRO': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Hydrogen',
#   'FullName': 'Hydrogen (HYDRO)',
#   'FullyPremined': '0',
#   'Id': '888283',
#   'ImageUrl': '/media/33187856/rsz_prd5wxkj_400x400-1.jpg',
#   'Name': 'HYDRO',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xebbdf302c940c6bfd49c6b165f457fdb324649bc',
#   'SortOrder': '2729',
#   'Sponsored': False,
#   'Symbol': 'HYDRO',
#   'TotalCoinSupply': '11111111111',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/hydro/overview'},
#  'SHPING': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Shping Coin',
#   'FullName': 'Shping Coin (SHPING)',
#   'FullyPremined': '0',
#   'Id': '782954',
#   'ImageUrl': '/media/27010884/shping.png',
#   'Name': 'SHPING',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x7c84e62859d0715eb77d1b1c4154ecd6abb21bec',
#   'SortOrder': '2359',
#   'Sponsored': False,
#   'Symbol': 'SHPING',
#   'TotalCoinSupply': '10000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/shping/overview'},
#  'HMP': {'Algorithm': 'Scrypt-n',
#   'BuiltOn': 'N/A',
#   'CoinName': 'HempCoin',
#   'FullName': 'HempCoin (HMP)',
#   'FullyPremined': '0',
#   'Id': '20655',
#   'ImageUrl': '/media/350941/hmp.png',
#   'Name': 'HMP',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '551',
#   'Sponsored': False,
#   'Symbol': 'HMP',
#   'TotalCoinSupply': '5000000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/hmp/overview'},
#  'ECASH': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Ethereum Cash',
#   'FullName': 'Ethereum Cash (ECASH)',
#   'FullyPremined': '0',
#   'Id': '355117',
#   'ImageUrl': '/media/14543971/ecash.png',
#   'Name': 'ECASH',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x5d21ef5f25a985380b65c8e943a0082feda0db84',
#   'SortOrder': '1751',
#   'Sponsored': False,
#   'Symbol': 'ECASH',
#   'TotalCoinSupply': '15000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ecash/overview'},
#  'KRONE': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Kronecoin',
#   'FullName': 'Kronecoin (KRONE)',
#   'FullyPremined': '0',
#   'Id': '247703',
#   'ImageUrl': '/media/9350770/krone.png',
#   'Name': 'KRONE',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1538',
#   'Sponsored': False,
#   'Symbol': 'KRONE',
#   'TotalCoinSupply': '84000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/krone/overview'},
#  'KRL': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Kryll',
#   'FullName': 'Kryll (KRL)',
#   'FullyPremined': '0',
#   'Id': '877048',
#   'ImageUrl': '/media/32655864/krl.jpg',
#   'Name': 'KRL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x464eBE77c293E473B48cFe96dDCf88fcF7bFDAC0',
#   'SortOrder': '2684',
#   'Sponsored': False,
#   'Symbol': 'KRL',
#   'TotalCoinSupply': '49417348',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/krl/overview'},
#  'BWS': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BitcoinWSpectrum',
#   'FullName': 'BitcoinWSpectrum (BWS)',
#   'FullyPremined': '0',
#   'Id': '907885',
#   'ImageUrl': '/media/34077424/bws.jpg',
#   'Name': 'BWS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2892',
#   'Sponsored': False,
#   'Symbol': 'BWS',
#   'TotalCoinSupply': '100262205',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/bws/overview'},
#  'ANTS': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'ANTS Reloaded',
#   'FullName': 'ANTS Reloaded (ANTS)',
#   'FullyPremined': '0',
#   'Id': '898986',
#   'ImageUrl': '/media/33434287/ants.jpg',
#   'Name': 'ANTS',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x1cCc29f9CEd9d1a5cE81a7262EAC8FcD7ecA5788',
#   'SortOrder': '2801',
#   'Sponsored': False,
#   'Symbol': 'ANTS',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ants/overview'},
#  'POST': {'Algorithm': 'N/A',
#   'BuiltOn': 'N/A',
#   'CoinName': 'PostCoin',
#   'FullName': 'PostCoin (POST)',
#   'FullyPremined': '0',
#   'Id': '20444',
#   'ImageUrl': '/media/350917/post.png',
#   'Name': 'POST',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '537',
#   'Sponsored': False,
#   'Symbol': 'POST',
#   'TotalCoinSupply': '15081003',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/post/overview'},
#  'MARX': {'Algorithm': 'X11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'MarxCoin',
#   'FullName': 'MarxCoin (MARX)',
#   'FullyPremined': '0',
#   'Id': '43818',
#   'ImageUrl': '/media/1382578/marx.png',
#   'Name': 'MARX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1078',
#   'Sponsored': False,
#   'Symbol': 'MARX',
#   'TotalCoinSupply': '100640000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/marx/overview'},
#  'DKC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'DarkKnightCoin',
#   'FullName': 'DarkKnightCoin (DKC)',
#   'FullyPremined': '0',
#   'Id': '30920',
#   'ImageUrl': '/media/351870/dkc.png',
#   'Name': 'DKC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '875',
#   'Sponsored': False,
#   'Symbol': 'DKC',
#   'TotalCoinSupply': '24000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/dkc/overview'},
#  'POA': {'Algorithm': 'Proof-of-Authority',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Poa Network',
#   'FullName': 'Poa Network (POA)',
#   'FullyPremined': '0',
#   'Id': '793845',
#   'ImageUrl': '/media/27010991/poa.png',
#   'Name': 'POA',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoA',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2407',
#   'Sponsored': False,
#   'Symbol': 'POA',
#   'TotalCoinSupply': '252460800',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/poa/overview'},
#  'MCAR': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'MasterCar',
#   'FullName': 'MasterCar (MCAR)',
#   'FullyPremined': '0',
#   'Id': '45612',
#   'ImageUrl': '/media/1382659/mcar.png',
#   'Name': 'MCAR',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '1102',
#   'Sponsored': False,
#   'Symbol': 'MCAR',
#   'TotalCoinSupply': '2991837',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/mcar/overview'},
#  'NBT': {'Algorithm': 'SHA256',
#   'BuiltOn': 'N/A',
#   'CoinName': 'NuBits',
#   'FullName': 'NuBits (NBT)',
#   'FullyPremined': '0',
#   'Id': '5287',
#   'ImageUrl': '/media/20363/nbt.png',
#   'Name': 'NBT',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '256',
#   'Sponsored': False,
#   'Symbol': 'NBT',
#   'TotalCoinSupply': 'N/A',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/nbt/overview'},
#  'AID': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'AidCoin',
#   'FullName': 'AidCoin (AID)',
#   'FullyPremined': '0',
#   'Id': '368770',
#   'ImageUrl': '/media/14913433/aidcoin.png',
#   'Name': 'AID',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0x37e8789bb9996cac9156cd5f5fd32599e6b91289',
#   'SortOrder': '1780',
#   'Sponsored': False,
#   'Symbol': 'AID',
#   'TotalCoinSupply': '100000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/aid/overview'},
#  'CAP': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'BottleCaps',
#   'FullName': 'BottleCaps (CAP)',
#   'FullyPremined': '0',
#   'Id': '4408',
#   'ImageUrl': '/media/20017/cap.png',
#   'Name': 'CAP',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '77',
#   'Sponsored': False,
#   'Symbol': 'CAP',
#   'TotalCoinSupply': '47433600',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/cap/overview'},
#  'SGN': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Signals Network',
#   'FullName': 'Signals Network (SGN)',
#   'FullyPremined': '0',
#   'Id': '715817',
#   'ImageUrl': '/media/27010455/sgn.png',
#   'Name': 'SGN',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'N/A',
#   'SmartContractAddress': '0xb2135ab9695a7678dd590b1a996cb0f37bcb0718',
#   'SortOrder': '2147',
#   'Sponsored': False,
#   'Symbol': 'SGN',
#   'TotalCoinSupply': '150000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/sgn/overview'},
#  'HEX': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'HexCoin',
#   'FullName': 'HexCoin (HEX)',
#   'FullyPremined': '0',
#   'Id': '913735',
#   'ImageUrl': '/media/34155565/hex.png',
#   'Name': 'HEX',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2970',
#   'Sponsored': False,
#   'Symbol': 'HEX',
#   'TotalCoinSupply': '22105263',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/hex/overview'},
#  'QRL': {'Algorithm': 'N/A',
#   'BuiltOn': '7605',
#   'CoinName': 'Quantum Resistant Ledger',
#   'FullName': 'Quantum Resistant Ledger (QRL)',
#   'FullyPremined': '0',
#   'Id': '127667',
#   'ImageUrl': '/media/1383543/qrl.png',
#   'Name': 'QRL',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoS',
#   'SmartContractAddress': '0x697beac28b09e122c4332d163985e8a73121b97f',
#   'SortOrder': '1248',
#   'Sponsored': False,
#   'Symbol': 'QRL',
#   'TotalCoinSupply': '65000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/qrl/overview'},
#  'TAM': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'TamaGucci',
#   'FullName': 'TamaGucci (TAM)',
#   'FullyPremined': '0',
#   'Id': '6411',
#   'ImageUrl': '/media/20565/tam.png',
#   'Name': 'TAM',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW/PoS/PoC',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '409',
#   'Sponsored': False,
#   'Symbol': 'TAM',
#   'TotalCoinSupply': '5300000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/tam/overview'},
#  'ITZ': {'Algorithm': 'C11',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Interzone',
#   'FullName': 'Interzone (ITZ)',
#   'FullyPremined': '0',
#   'Id': '709089',
#   'ImageUrl': '/media/25792662/itz.png',
#   'Name': 'ITZ',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '2126',
#   'Sponsored': False,
#   'Symbol': 'ITZ',
#   'TotalCoinSupply': '23000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/itz/overview'},
#  'LTC': {'Algorithm': 'Scrypt',
#   'BuiltOn': 'N/A',
#   'CoinName': 'Litecoin',
#   'FullName': 'Litecoin (LTC)',
#   'FullyPremined': '0',
#   'Id': '3808',
#   'ImageUrl': '/media/19782/litecoin-logo.png',
#   'Name': 'LTC',
#   'PreMinedValue': 'N/A',
#   'ProofType': 'PoW',
#   'SmartContractAddress': 'N/A',
#   'SortOrder': '3',
#   'Sponsored': False,
#   'Symbol': 'LTC',
#   'TotalCoinSupply': '84000000',
#   'TotalCoinsFreeFloat': 'N/A',
#   'Url': '/coins/ltc/overview'},
#  ...}

# %%
list_of_coins=coins['Data']

# %%
len(list_of_coins.keys()) #num of crypto
# Out:
# 2775
